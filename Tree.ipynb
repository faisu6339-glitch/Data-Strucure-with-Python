# %% [markdown]
# <a href="https://colab.research.google.com/github/faisu6339-glitch/Data-Strucure-with-Python/blob/main/Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tree

# %% [markdown]
# A tree is a hierarchical data structure that consists of nodes connected by edges. It simulates a tree structure with a root value and subtrees of children with a parent node, represented as a set of linked nodes.
#
# In Python, you can implement a tree using classes where each node object has a value and a list of references to its children nodes. Here's a basic example of how you might represent a tree node and build a simple tree:
#
# ```python
# class TreeNode:
#     def __init__(self, data):
#         self.data = data
#         self.children = []
#
#     def add_child(self, child_node):
#         self.children.append(child_node)
#
#     def __str__(self, level=0):
#         ret = "  " * level + str(self.data) + "\n"
#         for child in self.children:
#             ret += child.__str__(level + 1)
#         return ret
#
# # Example usage:
# root = TreeNode("Root")
#
# child1 = TreeNode("Child 1")
# child2 = TreeNode("Child 2")
#
# root.add_child(child1)
# root.add_child(child2)
#
# grandchild1 = TreeNode("Grandchild 1")
# grandchild2 = TreeNode("Grandchild 2")
#
# child1.add_child(grandchild1)
# child1.add_child(grandchild2)
#
# print(root)
# ```
#
# **Key concepts of a tree data structure:**
#
# *   **Root:** The topmost node in a tree. It has no parent.
# *   **Node:** An entity that stores data and links to other nodes.
# *   **Edge:** The link between two nodes.
# *   **Parent:** A node that has one or more child nodes.
# *   **Child:** A node directly connected to another node one level below it.
# *   **Leaf:** A node that has no children.
# *   **Subtree:** A tree consisting of a node and all its descendants.
# *   **Depth:** The length of the path from the root to a node.
# *   **Height:** The length of the path from the deepest leaf to the root.
#
# There are various types of trees, such as binary trees, binary search trees, AVL trees, and B-trees, each with specific properties and use cases.

# %% [markdown]
#               10
#              /  \
#             20   30
#            / \     \
#           40  50    60

# %% [markdown]
# # 1. Creating a Tree Node in Python

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None


# Create root
root = Node(10)

# Level 1
root.left = Node(20)
root.right = Node(30)

# Level 2
root.left.left = Node(40)
root.left.right = Node(50)

root.right.left = Node(60)
root.right.right = Node(70)


# Print nodes
print("Root:", root.data)
print("Left child:", root.left.data)
print("Right child:", root.right.data)

print("Left-Left:", root.left.left.data)
print("Left-Right:", root.left.right.data)

print("Right-Left:", root.right.left.data)
print("Right-Right:", root.right.right.data)
# Out:
# Root: 10
# Left child: 20
# Right child: 30
# Left-Left: 40
# Left-Right: 50
# Right-Left: 60
# Right-Right: 70

# %% [markdown]
# # Inorder

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None


def inorder(root):
    if root is None:
        return

    inorder(root.left)
    print(root.data, end=" ")
    inorder(root.right)


root = Node(10)
root.left = Node(20)
root.right = Node(30)

root.left.left = Node(40)
root.left.right = Node(50)

inorder(root)
# Out:
# 40 20 50 10 30

# %% [markdown]
#         10
#        /  \
#       20   30
#      / \
#     40  50

# %% [markdown]
# # Preorder

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None


def preorder(root):
    if root is None:
        return

    print(root.data, end=" ")
    preorder(root.left)
    preorder(root.right)


root = Node(10)
root.left = Node(20)
root.right = Node(30)

root.left.left = Node(40)
root.left.right = Node(50)

preorder(root)
# Out:
# 10 20 40 50 30

# %% [markdown]
#         10
#        /  \
#       20   30
#      / \
#     40  50

# %% [markdown]
# # Post Order

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None


# Postorder Traversal
# Left -> Right -> Root
def postorder(root):
    if root is None:
        return

    postorder(root.left)
    postorder(root.right)
    print(root.data, end=" ")


# Create Tree
root = Node(10)

root.left = Node(20)
root.right = Node(30)

root.left.left = Node(40)
root.left.right = Node(50)


# Postorder Traversal
print("Postorder:")
postorder(root)
# Out:
# Postorder:
# 40 50 20 30 10
